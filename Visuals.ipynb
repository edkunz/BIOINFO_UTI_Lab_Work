# %%
import pandas as pd

data = pd.read_csv('fake_patient_data.csv')
data
# Out:
#    Age_Range Diabetic Catheter E_coli K_pneumoniae P_mirabilis E_faecalis  \
# 0        81+        N        N      N            N           Y          N
# 1       0-18        Y        Y      Y            Y           Y          Y
# 2      36-50        Y        Y      Y            N           N          Y
# 3        81+        N        Y      N            Y           N          N
# 4       0-18        Y        Y      N            N           Y          N
# ..       ...      ...      ...    ...          ...         ...        ...
# 95       81+        Y        N      Y            Y           N          Y
# 96     66-80        N        Y      N            Y           N          Y
# 97     66-80        N        N      N            Y           N          N
# 98     36-50        N        Y      N            N           N          N
# 99       81+        Y        N      Y            N           Y          N
#
#    S_saprophyticus P_aeruginosa C_albicans
# ...
